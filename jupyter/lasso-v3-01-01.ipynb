# %%
rels = {'TestPositive': ['Chestpain!Fatigue!RaceWhite',
  'Chills!Headaches!RaceWhite',
  'Cough!IgnoreRespSymp!RaceWhite',
  'Fever!Chestpain!Fatigue',
  'Fever!Headaches',
  'Fever!LossTaste!Cough',
  'Fever!MuscleAches!RaceWhite',
  'Headaches!Cough!RaceWhite',
  'Headaches!Runnynose!Cough',
  'LossAppetite!Cough!RaceWhite',
  'LossTaste!Headaches!RaceWhite',
  'LossTaste!Runnynose!Cough',
  'Chestpain!Chills!MuscleAches'],
 'Fever': ['Chestpain',
  'Chestpain!GenderFemale',
  'Chills!MuscleAches',
  'Cough',
  'Difficultybreathing',
  'IgnoreRespSymp!RaceWhite',
  'JointPain!Headaches',
  'Runnynose!RaceWhite',
  'Sorethroat',
  'Wheezing!RaceWhite'],
 'Chills': ['Fatigue!Sorethroat!Cough',
  'Headaches!Sorethroat!Runnynose',
  'MuscleAches!Fatigue',
  'MuscleAches!Fatigue!Cough',
  'MuscleAches!Fatigue!Headaches',
  'MuscleAches!Fatigue!Sorethroat',
  'MuscleAches!Headaches!RaceWhite',
  'MuscleAches!Sorethroat!Runnynose'],
 'Cough': ['IgnoreInflamSymp',
  'IgnoreRespSymp',
  'IgnoreRespSymp!Age30orMore',
  'RaceWhite'],
 'Runnynose': ['Cough', 'Cough!RaceWhite', 'RaceWhite'],
 'IgnoreRespSymp': [],
 'Headaches': ['IgnoreNeuroSymp',
  'Runnynose!Cough',
  'Sorethroat',
  'Sorethroat!Cough!RaceWhite',
  'Sorethroat!GenderFemale',
  'Sorethroat!Runnynose!Cough'],
 'Chestpain': ['Difficultybreathing!Fatigue!Headaches',
  'Difficultybreathing!MuscleAches!Fatigue',
  'Difficultybreathing!MuscleAches!Headaches',
  'Fatigue',
  'Fatigue!RaceWhite',
  'LossAppetite!Chills!Cough',
  'LossAppetite!Diarrhea',
  'LossAppetite!Headaches!Sorethroat',
  'MuscleAches!RaceWhite'],
 'Fatigue': ['Cough!Age30orMore',
  'Cough!GenderFemale!Age30orMore',
  'Headaches',
  'Headaches!RaceWhite',
  'Headaches!Sorethroat',
  'Headaches!Sorethroat!Cough',
  'Headaches!Sorethroat!RaceWhite'],
 'MuscleAches': ['Cough!Age30orMore',
  'Cough!IgnoreRespSymp!IgnoreInflamSymp',
  'Fatigue',
  'Fatigue!Headaches!RaceWhite',
  'Fatigue!Headaches!Runnynose',
  'Fatigue!Sorethroat',
  'Fatigue!Sorethroat!Cough',
  'Headaches!Sorethroat!Cough'],
 'LossTaste': ['AbdominalPain!Age30orMore',
  'Cough!IgnoreNeuroSymp!RaceWhite',
  'Diarrhea!Runnynose!RaceWhite',
  'ExcessSweat!Cough!RaceWhite',
  'Fatigue!Cough!Age30orMore',
  'Fatigue!RaceWhite',
  'IgnoreNeuroSymp!RaceWhite!GenderFemale',
  'JointPain',
  'JointPain!RaceWhite',
  'LossAppetite'],
 'LossAppetite': ['Chills!MuscleAches!Sorethroat',
  'Cough!GenderFemale',
  'Diarrhea!Fatigue!Sorethroat',
  'Difficultybreathing!Chills!Runnynose',
  'Difficultybreathing!MuscleAches!Fatigue',
  'Fatigue!Cough',
  'Fatigue!RaceWhite',
  'MuscleAches!Headaches!Runnynose',
  'MuscleAches!Sorethroat'],
 'AbdominalPain': ['Diarrhea!Runnynose',
  'Diarrhea!Runnynose!Cough',
  'Fatigue!GenderFemale',
  'IgnoreGastroSymp',
  'IgnoreRespSymp!IgnoreGastroSymp',
  'MuscleAches!Cough',
  'MuscleAches!IgnoreRespSymp',
  'Runnynose!IgnoreGastroSymp',
  'Runnynose!IgnoreRespSymp!IgnoreNeuroSymp'],
 'ExcessSweat': ['Headaches!Cough!IgnoreNeuroSymp',
  'Headaches!IgnoreGastroSymp',
  'Headaches!IgnoreNeuroSymp',
  'Headaches!Runnynose!Cough',
  'Headaches!Sorethroat!GenderFemale'],
 'IgnoreInflamSymp': [],
 'Sorethroat': ['Cough',
  'Runnynose!Cough',
  'Runnynose!Cough!GenderFemale',
  'Runnynose!GenderFemale',
  'Runnynose!IgnoreRespSymp',
  'Runnynose!RaceWhite'],
 'Difficultybreathing': ['Chills!Headaches!Runnynose',
  'Chills!MuscleAches',
  'Chills!MuscleAches!Fatigue',
  'Chills!Runnynose!RaceWhite',
  'Diarrhea!IgnoreRespSymp!Age30orMore',
  'Diarrhea!MuscleAches!Headaches',
  'Diarrhea!Runnynose',
  'Diarrhea!Sorethroat!Runnynose',
  'IgnoreNeuroSymp',
  'IgnoreNeuroSymp!Age30orMore',
  'MuscleAches!Cough',
  'MuscleAches!IgnoreRespSymp!IgnoreInflamSymp',
  'MuscleAches!Sorethroat!Runnynose'],
 'IgnoreNeuroSymp': [],
 'Wheezing': ['Chestpain',
  'Difficultybreathing!RaceWhite',
  'LossAppetite!Diarrhea!Cough',
  'LossAppetite!MuscleAches!Runnynose',
  'LossBalance!Age30orMore',
  'LossTaste',
  'MuscleAches!Runnynose',
  'Shivering!RaceWhite',
  'Shortnessofbreath!Diarrhea',
  'Shortnessofbreath!Difficultybreathing',
  'Shortnessofbreath!Runnynose',
  'Shortnessofbreath!Sorethroat!Cough'],
 'JointPain': ['Chestpain!LossAppetite',
  'Chestpain!Sorethroat!RaceWhite',
  'Chills!MuscleAches!Sorethroat',
  'Diarrhea!Cough',
  'Diarrhea!Cough!RaceWhite',
  'Diarrhea!Runnynose!Cough',
  'Difficultybreathing!Runnynose!Cough',
  'Difficultybreathing!Sorethroat!RaceWhite',
  'IgnoreGastroSymp',
  'IgnoreInflamSymp',
  'IgnoreRespSymp!IgnoreNeuroSymp',
  'LossAppetite!RaceWhite',
  'Cough!IgnoreInflamSymp'],
 'Diarrhea': ['Chills!Fatigue!Cough',
  'Fatigue!Headaches!Sorethroat',
  'Fatigue!RaceWhite',
  'Headaches!Age30orMore',
  'Headaches!Sorethroat!Runnynose',
  'IgnoreGastroSymp',
  'IgnoreGastroSymp!Age30orMore',
  'MuscleAches!Runnynose!Cough',
  'MuscleAches!Runnynose!RaceWhite',
  'MuscleAches!Sorethroat!Runnynose',
  'Runnynose!Cough!IgnoreRespSymp',
  'Runnynose!IgnoreRespSymp!IgnoreGastroSymp'],
 'Shivering': ['Chestpain',
  'Chestpain!Cough!RaceWhite',
  'Chestpain!Headaches',
  'Chestpain!MuscleAches',
  'Chestpain!RaceWhite',
  'JointPain',
  'JointPain!Cough',
  'JointPain!LossAppetite!Fatigue',
  'MuscleAches!GenderFemale',
  'MuscleAches!Runnynose'],
 'LossBalance': ['AbdominalPain',
  'AbdominalPain!RaceWhite',
  'Cough!IgnoreRespSymp!IgnoreNeuroSymp',
  'Diarrhea!Cough!IgnoreRespSymp',
  'Difficultybreathing!Runnynose!IgnoreRespSymp',
  'JointPain!Cough!IgnoreRespSymp',
  'Runnynose!Cough!IgnoreNeuroSymp'],
 'IgnoreGastroSymp': [],
 'Shortnessofbreath': ['Chestpain',
  'Chestpain!Cough!GenderFemale',
  'Chestpain!Difficultybreathing!Cough',
  'Chestpain!MuscleAches!Runnynose',
  'Chestpain!Runnynose',
  'Diarrhea!Fatigue!Runnynose',
  'Diarrhea!RaceWhite',
  'LossAppetite!Chills!MuscleAches',
  'LossAppetite!Chills!RaceWhite',
  'LossAppetite!MuscleAches!GenderFemale',
  'MuscleAches!RaceWhite!Age30orMore']}

# %%
from typing import Tuple, Dict, List, Any

def trim_parents(parents: List[str]):
    def is_contained_within(pa, pa_sets):
        for s in pa_sets:
            if pa in s:
                return True
        return False
    
    intera_pas = [set(pa.split('!')) for pa in parents if pa.find('!') != -1]
    single_pas = [pa for pa in parents if pa.find('!') < 0 and is_contained_within(pa, intera_pas) is False]
    pas = single_pas + [pa for pa in parents if pa.find('!') != -1]
    return pas

parents = {k: trim_parents(pas) for k, pas in rels.items() if len(pas) > 0}
parents
# Out:
# {'TestPositive': ['Chestpain!Fatigue!RaceWhite',
#   'Chills!Headaches!RaceWhite',
#   'Cough!IgnoreRespSymp!RaceWhite',
#   'Fever!Chestpain!Fatigue',
#   'Fever!Headaches',
#   'Fever!LossTaste!Cough',
#   'Fever!MuscleAches!RaceWhite',
#   'Headaches!Cough!RaceWhite',
#   'Headaches!Runnynose!Cough',
#   'LossAppetite!Cough!RaceWhite',
#   'LossTaste!Headaches!RaceWhite',
#   'LossTaste!Runnynose!Cough',
#   'Chestpain!Chills!MuscleAches'],
#  'Fever': ['Cough',
#   'Difficultybreathing',
#   'Sorethroat',
#   'Chestpain!GenderFemale',
#   'Chills!MuscleAches',
#   'IgnoreRespSymp!RaceWhite',
#   'JointPain!Headaches',
#   'Runnynose!RaceWhite',
#   'Wheezing!RaceWhite'],
#  'Chills': ['Fatigue!Sorethroat!Cough',
#   'Headaches!Sorethroat!Runnynose',
#   'MuscleAches!Fatigue',
#   'MuscleAches!Fatigue!Cough',
#   'MuscleAches!Fatigue!Headaches',
#   'MuscleAches!Fatigue!Sorethroat',
#   'MuscleAches!Headaches!RaceWhite',
#   'MuscleAches!Sorethroat!Runnynose'],
# ...

# %%
import networkx as nx
from networkx.algorithms.dag import is_directed_acyclic_graph

g = nx.DiGraph()

for ch, pas in parents.items():
    for pa in pas:
        g.add_edge(pa, ch)
        
        if not is_directed_acyclic_graph(g):
            g.remove_edge(pa, ch)
            
    for pa in pas:
        pa_set = pa.split('!')
        if len(pa_set) < 2:
            continue
        
        for single_pa in pa_set:
            g.add_edge(single_pa, pa)
            
            if not is_directed_acyclic_graph(g):
                g.remove_edge(single_pa, pa)

# %% [markdown]
# - [ConnectionStyle](https://matplotlib.org/stable/api/_as_gen/matplotlib.patches.ConnectionStyle.html#matplotlib.patches.ConnectionStyle)
# - [FancyArrowPatch](https://matplotlib.org/stable/api/_as_gen/matplotlib.patches.FancyArrowPatch.html#matplotlib.patches.FancyArrowPatch)
# - [draw_networkx_edge](https://networkx.org/documentation/stable/reference/generated/networkx.drawing.nx_pylab.draw_networkx_edges.html)
# - [creating curved edges with networkx](https://stackoverflow.com/questions/52588453/creating-curved-edges-with-networkx-in-python3)
# - [graphviz_layout](https://networkx.org/documentation/stable/reference/generated/networkx.drawing.nx_agraph.graphviz_layout.html)
# - [splines](http://www.graphviz.org/docs/attrs/splines/)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(50, 80))

# pos = nx.nx_agraph.graphviz_layout(g, prog='dot', args='-Kdot -Eoverlap=false -Esplines=polyline')
pos = nx.nx_agraph.graphviz_layout(g, prog='dot', args='-Kdot')
params = {
    'node_size': 1000,
    'node_shape': 'o',
    'alpha': 0.5,
    'font_size': 10,
    'font_color': 'k',
    'font_family': 'monospace',
    'width': 0.5,
    'connectionstyle': 'arc3,rad=0.5'
}

nx.draw(g, pos=pos, with_labels=True, font_weight='bold', node_color='r', ax=ax, **params)
plt.savefig('../data/gmu-covid.png')
plt.savefig('../data/gmu-covid.svg')

# %%
import json

with open('../data/gmu-covid-parents.json', 'w') as f:
    d = {n: list(g.predecessors(n)) for n in g.nodes()}
    json.dump(d, f, indent=1)

# %%
nx.write_gpickle(g, '../data/gmu-covid-networkx.gpickle')
